# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# ## Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized. This aims to provide a quick reference for common languages, libraries, and tools used in the field.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. **Python**
# 2. **R**
# 3. **SQL**
# 4. **Julia**
# 5. **Scala**

# %% [markdown]
# ## Data Science Libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. **Pandas** (for data manipulation and analysis)
# 2. **NumPy** (for numerical computing)
# 3. **Matplotlib** (for plotting and visualization)
# 4. **Scikit-learn** (for machine learning)
# 5. **TensorFlow / PyTorch** (for deep learning)

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools |
# | :------------------ |
# | JupyterLab / Notebook |
# | RStudio |
# | VS Code (with extensions) |
# | Apache Spark |
# | Tableau |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# # This is a simple arithmetic expression to multiply then add integers.
# result = (3 * 4) + 5
# print(result)

# %% [markdown]
# # This code will convert 200 minutes to hours by dividing by 60.
# minutes = 200
# hours = minutes / 60
# print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# ## Objectives
#
# In this notebook, we achieved the following objectives:
#
# * List popular languages for Data Science.
# * Identify key Data Science libraries.
# * Create a table of common Data Science tools.
# * Demonstrate basic arithmetic operations in a Python code cell.
# * Convert units (minutes to hours) using a Python code cell.

# %% [markdown]
# ## Author
#
# Nguyen Ngoc Tien Manh
